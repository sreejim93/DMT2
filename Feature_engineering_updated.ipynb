# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/vu-dmt-assigment-2-2023/submission_sample.csv
# /kaggle/input/vu-dmt-assigment-2-2023/test_set_VU_DM.csv
# /kaggle/input/vu-dmt-assigment-2-2023/training_set_VU_DM.csv

# %% [markdown]
# # Reading and Cleaning Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import seaborn as sns
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
print(os.listdir('../input/vu-dmt-assigment-2-2023/'))
# Out:
# ['submission_sample.csv', 'test_set_VU_DM.csv', 'training_set_VU_DM.csv']

# %% [markdown]
# # Reading the Dataset

# %%
train= pd.read_csv("/kaggle/input/vu-dmt-assigment-2-2023/training_set_VU_DM.csv")

# %%
print(train.shape)
# Out:
# (4958347, 54)

# %%
train = train.dropna(axis=1,how="any")

# %%
train
# Out:
#          srch_id            date_time  site_id  visitor_location_country_id  \
# 0              1  2013-04-04 08:32:15       12                          187
# 1              1  2013-04-04 08:32:15       12                          187
# 2              1  2013-04-04 08:32:15       12                          187
# 3              1  2013-04-04 08:32:15       12                          187
# 4              1  2013-04-04 08:32:15       12                          187
# ...          ...                  ...      ...                          ...
# 4958342   332785  2013-06-30 19:55:18        5                          219
# 4958343   332785  2013-06-30 19:55:18        5                          219
# 4958344   332785  2013-06-30 19:55:18        5                          219
# 4958345   332785  2013-06-30 19:55:18        5                          219
# 4958346   332785  2013-06-30 19:55:18        5                          219
#
#          prop_country_id  prop_id  prop_starrating  prop_brand_bool  \
# 0                    219      893                3                1
# 1                    219    10404                4                1
# 2                    219    21315                3                1
# 3                    219    27348                2                1
# 4                    219    29604                4                1
# ...                  ...      ...              ...              ...
# 4958342              219    77700                3                1
# 4958343              219    88083                3                1
# 4958344              219    94508                3                1
# 4958345              219   128360                3                1
# 4958346              219   134949                3                1
#
#          prop_location_score1  prop_log_historical_price  ...  \
# 0                        2.83                       4.95  ...
# 1                        2.20                       5.03  ...
# 2                        2.20                       4.92  ...
# 3                        2.83                       4.39  ...
# 4                        2.64                       4.93  ...
# ...                       ...                        ...  ...
# 4958342                  1.61                       0.00  ...
# 4958343                  1.95                       0.00  ...
# 4958344                  1.10                       0.00  ...
# 4958345                  1.95                       0.00  ...
# 4958346                  1.10                       0.00  ...
#
#          srch_destination_id  srch_length_of_stay  srch_booking_window  \
# 0                      23246                    1                    0
# 1                      23246                    1                    0
# 2                      23246                    1                    0
# 3                      23246                    1                    0
# 4                      23246                    1                    0
# ...                      ...                  ...                  ...
# 4958342                16974                    1                   21
# 4958343                16974                    1                   21
# 4958344                16974                    1                   21
# 4958345                16974                    1                   21
# 4958346                16974                    1                   21
#
#          srch_adults_count  srch_children_count  srch_room_count  \
# 0                        4                    0                1
# 1                        4                    0                1
# 2                        4                    0                1
# 3                        4                    0                1
# 4                        4                    0                1
# ...                    ...                  ...              ...
# 4958342                  3                    0                1
# 4958343                  3                    0                1
# 4958344                  3                    0                1
# 4958345                  3                    0                1
# 4958346                  3                    0                1
#
#          srch_saturday_night_bool  random_bool  click_bool  booking_bool
# 0                               1            1           0             0
# 1                               1            1           0             0
# 2                               1            1           0             0
# 3                               1            1           0             0
# 4                               1            1           0             0
# ...                           ...          ...         ...           ...
# 4958342                         0            0           0             0
# 4958343                         0            0           0             0
# 4958344                         0            0           0             0
# 4958345                         0            0           1             1
# 4958346                         0            0           0             0
#
# [4958347 rows x 23 columns]

# %%
train.shape
# Out:
# (4958347, 23)

# %%
train.isnull().sum()
# Out:
# srch_id                        0
# date_time                      0
# site_id                        0
# visitor_location_country_id    0
# prop_country_id                0
# prop_id                        0
# prop_starrating                0
# prop_brand_bool                0
# prop_location_score1           0
# prop_log_historical_price      0
# position                       0
# price_usd                      0
# promotion_flag                 0
# srch_destination_id            0
# srch_length_of_stay            0
# srch_booking_window            0
# srch_adults_count              0
# srch_children_count            0
# srch_room_count                0
# srch_saturday_night_bool       0
# random_bool                    0
# click_bool                     0
# booking_bool                   0
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4958347 entries, 0 to 4958346
# Data columns (total 23 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   srch_id                      int64
#  1   date_time                    object
#  2   site_id                      int64
#  3   visitor_location_country_id  int64
#  4   prop_country_id              int64
#  5   prop_id                      int64
#  6   prop_starrating              int64
#  7   prop_brand_bool              int64
#  8   prop_location_score1         float64
#  9   prop_log_historical_price    float64
#  10  position                     int64
#  11  price_usd                    float64
#  12  promotion_flag               int64
#  13  srch_destination_id          int64
#  14  srch_length_of_stay          int64
#  15  srch_booking_window          int64
#  16  srch_adults_count            int64
#  17  srch_children_count          int64
#  18  srch_room_count              int64
#  19  srch_saturday_night_bool     int64
#  20  random_bool                  int64
#  21  click_bool                   int64
#  22  booking_bool                 int64
# dtypes: float64(3), int64(19), object(1)
# memory usage: 870.1+ MB

# %%
train.describe()
# Out:
#             srch_id       site_id  visitor_location_country_id  \
# count  4.958347e+06  4.958347e+06                 4.958347e+06
# mean   1.663666e+05  9.953133e+00                 1.753405e+02
# std    9.611223e+04  7.646890e+00                 6.591625e+01
# min    1.000000e+00  1.000000e+00                 1.000000e+00
# 25%    8.293600e+04  5.000000e+00                 1.000000e+02
# 50%    1.665070e+05  5.000000e+00                 2.190000e+02
# 75%    2.497240e+05  1.400000e+01                 2.190000e+02
# max    3.327850e+05  3.400000e+01                 2.310000e+02
#
#        prop_country_id       prop_id  prop_starrating  prop_brand_bool  \
# count     4.958347e+06  4.958347e+06     4.958347e+06     4.958347e+06
# mean      1.739739e+02  7.007918e+04     3.180525e+00     6.346994e-01
# std       6.834525e+01  4.060992e+04     1.051024e+00     4.815144e-01
# min       1.000000e+00  1.000000e+00     0.000000e+00     0.000000e+00
# 25%       1.000000e+02  3.501000e+04     3.000000e+00     0.000000e+00
# 50%       2.190000e+02  6.963800e+04     3.000000e+00     1.000000e+00
# 75%       2.190000e+02  1.051680e+05     4.000000e+00     1.000000e+00
# max       2.300000e+02  1.408210e+05     5.000000e+00     1.000000e+00
#
#        prop_location_score1  prop_log_historical_price      position  ...  \
# count          4.958347e+06               4.958347e+06  4.958347e+06  ...
# mean           2.872589e+00               4.317913e+00  1.685624e+01  ...
# std            1.531011e+00               1.834869e+00  1.042566e+01  ...
# min            0.000000e+00               0.000000e+00  1.000000e+00  ...
# 25%            1.790000e+00               4.450000e+00  8.000000e+00  ...
# 50%            2.770000e+00               4.910000e+00  1.600000e+01  ...
# 75%            4.040000e+00               5.310000e+00  2.600000e+01  ...
# max            6.980000e+00               6.210000e+00  4.000000e+01  ...
#
#        srch_destination_id  srch_length_of_stay  srch_booking_window  \
# count         4.958347e+06         4.958347e+06         4.958347e+06
# mean          1.404263e+04         2.385427e+00         3.747417e+01
# std           8.111843e+03         2.053243e+00         5.199341e+01
# min           2.000000e+00         1.000000e+00         0.000000e+00
# 25%           7.101000e+03         1.000000e+00         4.000000e+00
# 50%           1.354100e+04         2.000000e+00         1.700000e+01
# 75%           2.108400e+04         3.000000e+00         4.800000e+01
# max           2.841600e+04         5.700000e+01         4.920000e+02
#
#        srch_adults_count  srch_children_count  srch_room_count  \
# count       4.958347e+06         4.958347e+06     4.958347e+06
# mean        1.972637e+00         3.504918e-01     1.110525e+00
# std         8.570628e-01         7.325692e-01     4.172290e-01
# min         1.000000e+00         0.000000e+00     1.000000e+00
# 25%         2.000000e+00         0.000000e+00     1.000000e+00
# 50%         2.000000e+00         0.000000e+00     1.000000e+00
# 75%         2.000000e+00         0.000000e+00     1.000000e+00
# max         9.000000e+00         9.000000e+00     8.000000e+00
#
#        srch_saturday_night_bool   random_bool    click_bool  booking_bool
# count              4.958347e+06  4.958347e+06  4.958347e+06  4.958347e+06
# mean               5.022127e-01  2.959004e-01  4.474858e-02  2.791051e-02
# std                4.999952e-01  4.564465e-01  2.067514e-01  1.647165e-01
# min                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%                0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%                1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%                1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00
# max                1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
#
# [8 rows x 22 columns]

# %%
import seaborn as sns
df = train.corr()
print(df)
# Out:
# /tmp/ipykernel_34/2763570754.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df = train.corr()
#                               srch_id   site_id  visitor_location_country_id  \
# srch_id                      1.000000  0.003331                    -0.006097
# site_id                      0.003331  1.000000                    -0.305921
# visitor_location_country_id -0.006097 -0.305921                     1.000000
# prop_country_id             -0.005468 -0.312593                     0.482787
# prop_id                     -0.000166  0.002943                     0.000432
# prop_starrating             -0.001577  0.174845                    -0.112911
# prop_brand_bool             -0.003828 -0.196217                     0.182405
# prop_location_score1         0.000439  0.178399                    -0.121392
# prop_log_historical_price   -0.003434  0.028635                    -0.021898
# position                    -0.001505 -0.031194                     0.018716
# price_usd                   -0.000699 -0.000957                    -0.001791
# promotion_flag               0.000876  0.083634                    -0.032065
# srch_destination_id          0.000594  0.020410                     0.000219
# srch_length_of_stay         -0.001256  0.106386                    -0.097225
# srch_booking_window         -0.002946  0.168395                    -0.087573
# srch_adults_count            0.004007 -0.022573                     0.002687
# srch_children_count          0.000138 -0.038736                     0.012874
# srch_room_count              0.005654  0.024071                    -0.027091
# srch_saturday_night_bool     0.000531 -0.082649                     0.068939
# random_bool                 -0.000697  0.026814                    -0.037232
# click_bool                   0.000194  0.008497                    -0.004806
# booking_bool                 0.000487 -0.001354                     0.002524
#
#                              prop_country_id   prop_id  prop_starrating  \
# srch_id                            -0.005468 -0.000166        -0.001577
# site_id                            -0.312593  0.002943         0.174845
# visitor_location_country_id         0.482787  0.000432        -0.112911
# prop_country_id                     1.000000  0.000162        -0.161729
# prop_id                             0.000162  1.000000         0.002553
# prop_starrating                    -0.161729  0.002553         1.000000
# prop_brand_bool                     0.310493  0.000922         0.021329
# prop_location_score1               -0.183344 -0.003706         0.287322
# prop_log_historical_price          -0.021119 -0.001457         0.167723
# position                            0.029850 -0.000320        -0.107717
# price_usd                          -0.004450  0.000242         0.007770
# promotion_flag                     -0.041365  0.001528         0.173732
# srch_destination_id                -0.011439 -0.004845        -0.008623
# srch_length_of_stay                -0.084679  0.001863         0.091217
# srch_booking_window                -0.118640  0.000222         0.074016
# srch_adults_count                   0.028440  0.000213         0.006948
# srch_children_count                 0.057388 -0.000834        -0.031148
# srch_room_count                    -0.011804 -0.000144         0.037151
# srch_saturday_night_bool            0.076750  0.000125        -0.042530
# random_bool                        -0.030175  0.002507        -0.004763
# click_bool                         -0.006222  0.000246         0.030788
# booking_bool                        0.001227 -0.000508         0.021206
#
#                              prop_brand_bool  prop_location_score1  \
# srch_id                            -0.003828              0.000439
# site_id                            -0.196217              0.178399
# visitor_location_country_id         0.182405             -0.121392
# prop_country_id                     0.310493             -0.183344
# prop_id                             0.000922             -0.003706
# prop_starrating                     0.021329              0.287322
# prop_brand_bool                     1.000000             -0.184617
# prop_location_score1               -0.184617              1.000000
# prop_log_historical_price           0.001311              0.113209
# position                            0.023419              0.003340
# price_usd                          -0.000993              0.003369
# promotion_flag                     -0.118841              0.180326
# srch_destination_id                -0.024829             -0.006989
# srch_length_of_stay                -0.107402              0.117521
# srch_booking_window                -0.097656              0.119707
# srch_adults_count                   0.006918              0.019014
# srch_children_count                 0.036102             -0.020746
# srch_room_count                     0.021232              0.022457
# srch_saturday_night_bool            0.070321             -0.050374
# random_bool                        -0.048390              0.005867
# click_bool                          0.000866              0.002184
# booking_bool                        0.009991             -0.003273
#
#                              prop_log_historical_price  position  ...  \
# srch_id                                      -0.003434 -0.001505  ...
# site_id                                       0.028635 -0.031194  ...
# visitor_location_country_id                  -0.021898  0.018716  ...
# prop_country_id                              -0.021119  0.029850  ...
# prop_id                                      -0.001457 -0.000320  ...
# prop_starrating                               0.167723 -0.107717  ...
# prop_brand_bool                               0.001311  0.023419  ...
# prop_location_score1                          0.113209  0.003340  ...
# prop_log_historical_price                     1.000000 -0.008703  ...
# position                                     -0.008703  1.000000  ...
# price_usd                                    -0.000620 -0.001880  ...
# promotion_flag                                0.039050 -0.103621  ...
# srch_destination_id                          -0.003867 -0.003988  ...
# srch_length_of_stay                           0.033426 -0.006361  ...
# srch_booking_window                           0.079877 -0.008636  ...
# srch_adults_count                            -0.010369 -0.009098  ...
# srch_children_count                          -0.048204 -0.022136  ...
# srch_room_count                               0.000780 -0.024657  ...
# srch_saturday_night_bool                      0.000501 -0.003560  ...
# random_bool                                   0.007561 -0.015492  ...
# click_bool                                    0.003360 -0.164992  ...
# booking_bool                                 -0.000807 -0.147918  ...
#
#                              srch_destination_id  srch_length_of_stay  \
# srch_id                                 0.000594            -0.001256
# site_id                                 0.020410             0.106386
# visitor_location_country_id             0.000219            -0.097225
# prop_country_id                        -0.011439            -0.084679
# prop_id                                -0.004845             0.001863
# prop_starrating                        -0.008623             0.091217
# prop_brand_bool                        -0.024829            -0.107402
# prop_location_score1                   -0.006989             0.117521
# prop_log_historical_price              -0.003867             0.033426
# position                               -0.003988            -0.006361
# price_usd                               0.001742             0.001565
# promotion_flag                         -0.006274             0.115967
# srch_destination_id                     1.000000            -0.003812
# srch_length_of_stay                    -0.003812             1.000000
# srch_booking_window                    -0.003157             0.262616
# srch_adults_count                      -0.000952             0.011260
# srch_children_count                    -0.004670             0.038336
# srch_room_count                        -0.007233             0.002111
# srch_saturday_night_bool                0.000618            -0.293019
# random_bool                            -0.003828             0.176213
# click_bool                              0.001193             0.002647
# booking_bool                            0.000800            -0.024412
#
#                              srch_booking_window  srch_adults_count  \
# srch_id                                -0.002946           0.004007
# site_id                                 0.168395          -0.022573
# visitor_location_country_id            -0.087573           0.002687
# prop_country_id                        -0.118640           0.028440
# prop_id                                 0.000222           0.000213
# prop_starrating                         0.074016           0.006948
# prop_brand_bool                        -0.097656           0.006918
# prop_location_score1                    0.119707           0.019014
# prop_log_historical_price               0.079877          -0.010369
# position                               -0.008636          -0.009098
# price_usd                               0.001517           0.001955
# promotion_flag                          0.027074           0.017321
# srch_destination_id                    -0.003157          -0.000952
# srch_length_of_stay                     0.262616           0.011260
# srch_booking_window                     1.000000           0.110007
# srch_adults_count                       0.110007           1.000000
# srch_children_count                     0.052099           0.096640
# srch_room_count                         0.039504           0.471428
# srch_saturday_night_bool               -0.079922           0.063918
# random_bool                             0.148153           0.050721
# click_bool                              0.001707           0.004620
# booking_bool                           -0.019582          -0.005376
#
#                              srch_children_count  srch_room_count  \
# srch_id                                 0.000138         0.005654
# site_id                                -0.038736         0.024071
# visitor_location_country_id             0.012874        -0.027091
# prop_country_id                         0.057388        -0.011804
# prop_id                                -0.000834        -0.000144
# prop_starrating                        -0.031148         0.037151
# prop_brand_bool                         0.036102         0.021232
# prop_location_score1                   -0.020746         0.022457
# prop_log_historical_price              -0.048204         0.000780
# position                               -0.022136        -0.024657
# price_usd                               0.002528        -0.000703
# promotion_flag                         -0.004519         0.011597
# srch_destination_id                    -0.004670        -0.007233
# srch_length_of_stay                     0.038336         0.002111
# srch_booking_window                     0.052099         0.039504
# srch_adults_count                       0.096640         0.471428
# srch_children_count                     1.000000         0.135387
# srch_room_count                         0.135387         1.000000
# srch_saturday_night_bool               -0.003219        -0.010023
# random_bool                             0.015594        -0.003915
# click_bool                              0.006012         0.007044
# booking_bool                            0.003872         0.007948
#
#                              srch_saturday_night_bool  random_bool  \
# srch_id                                      0.000531    -0.000697
# site_id                                     -0.082649     0.026814
# visitor_location_country_id                  0.068939    -0.037232
# prop_country_id                              0.076750    -0.030175
# prop_id                                      0.000125     0.002507
# prop_starrating                             -0.042530    -0.004763
# prop_brand_bool                              0.070321    -0.048390
# prop_location_score1                        -0.050374     0.005867
# prop_log_historical_price                    0.000501     0.007561
# position                                    -0.003560    -0.015492
# price_usd                                   -0.001896    -0.001461
# promotion_flag                              -0.044601    -0.022626
# srch_destination_id                          0.000618    -0.003828
# srch_length_of_stay                         -0.293019     0.176213
# srch_booking_window                         -0.079922     0.148153
# srch_adults_count                            0.063918     0.050721
# srch_children_count                         -0.003219     0.015594
# srch_room_count                             -0.010023    -0.003915
# srch_saturday_night_bool                     1.000000    -0.028863
# random_bool                                 -0.028863     1.000000
# click_bool                                   0.001150     0.005819
# booking_bool                                 0.005478    -0.088891
#
#                              click_bool  booking_bool
# srch_id                        0.000194      0.000487
# site_id                        0.008497     -0.001354
# visitor_location_country_id   -0.004806      0.002524
# prop_country_id               -0.006222      0.001227
# prop_id                        0.000246     -0.000508
# prop_starrating                0.030788      0.021206
# prop_brand_bool                0.000866      0.009991
# prop_location_score1           0.002184     -0.003273
# prop_log_historical_price      0.003360     -0.000807
# position                      -0.164992     -0.147918
# price_usd                      0.000510      0.000067
# promotion_flag                 0.039440      0.036047
# srch_destination_id            0.001193      0.000800
# srch_length_of_stay            0.002647     -0.024412
# srch_booking_window            0.001707     -0.019582
# srch_adults_count              0.004620     -0.005376
# srch_children_count            0.006012      0.003872
# srch_room_count                0.007044      0.007948
# srch_saturday_night_bool       0.001150      0.005478
# random_bool                    0.005819     -0.088891
# click_bool                     1.000000      0.782889
# booking_bool                   0.782889      1.000000
#
# [22 rows x 22 columns]

# %%
import matplotlib.pyplot as plt
train[["promotion_flag","position"]].groupby("promotion_flag").sum().position.plot(kind="pie",shadow=True,autopct="%1.1f%%",radius=1.2,startangle=120)
plt.title("Promotion Graph")
plt.show()

# %%
# Get the index value counts in descending order
index_value_counts = train['promotion_flag'].value_counts(ascending=False)

# Select the top ten index values
top10_index = index_value_counts.head(10)

# Plot the bar chart
top10_index.plot.bar()

# Add labels and title
plt.xlabel('Say i = Yes')
plt.ylabel('Count')
plt.title('Top 10 hotels')

# Show the plot
plt.show()

# %%
train[["prop_brand_bool","position"]].groupby("prop_brand_bool").sum().position.plot(kind="pie",shadow=True,autopct="%1.1f%%",radius=1.2,startangle=120)
plt.title("Part of a major hotel chain")
plt.show()

# %%
train[["srch_saturday_night_bool","position"]].groupby("srch_saturday_night_bool").sum().position.plot(kind="pie",shadow=True,autopct="%1.1f%%",radius=1.2,startangle=120)
plt.title("Saty for weekend")
plt.show()

# %%
train[["click_bool","position"]].groupby("click_bool").sum().position.plot(kind="pie",shadow=True,autopct="%1.1f%%",radius=1.2,startangle=120)
plt.title("User status shows on sorted property")
plt.show()

# %%
train[["booking_bool","position"]].groupby("booking_bool").sum().position.plot(kind="pie",shadow=True,autopct="%1.1f%%",radius=1.2,startangle=120)
plt.title("Booking status shows on sorted property")
plt.show()

# %%
train[["random_bool","position"]].groupby("random_bool").sum().position.plot(kind="pie",shadow=True,autopct="%1.1f%%",radius=1.2,startangle=120)
plt.title("Display random  shows on sorted property")
plt.show()

# %%
# Get the index value counts in descending order
index_value_counts = train['prop_log_historical_price'].value_counts(ascending=False)

# Select the top ten index values
top10_index = index_value_counts.head(10)

# Plot the bar chart
top10_index.plot.bar()

# Add labels and title
plt.xlabel('Price in USD $')
plt.ylabel('Count')
plt.title('Top 10 Price by Count')

# Show the plot
plt.show()

# %%
train.visitor_location_country_id.plot(kind = 'hist',bins = 50,figsize = (12,12))
plt.show()

# %%
# Scatter Plot 
# x = attack, y = defense
train.plot(kind='scatter', x='prop_country_id', y='visitor_location_country_id',alpha = 0.5,color = 'red')
plt.xlabel('Property id')              # label = name of label
plt.ylabel('visitor_location_country_id')
plt.title('visitor_location_country_id Scatter Plot')
# Out:
# Text(0.5, 1.0, 'visitor_location_country_id Scatter Plot')

# %%
train.prop_starrating.plot(kind = 'hist',bins = 50,figsize = (12,10))
plt.show()

# %%
train.srch_children_count.plot(kind = 'hist',bins = 50,figsize = (12,10))
plt.show()

# %%
train.columns
# Out:
# Index(['srch_id', 'date_time', 'site_id', 'visitor_location_country_id',
#        'prop_country_id', 'prop_id', 'prop_starrating', 'prop_brand_bool',
#        'prop_location_score1', 'prop_log_historical_price', 'position',
#        'price_usd', 'promotion_flag', 'srch_destination_id',
#        'srch_length_of_stay', 'srch_booking_window', 'srch_adults_count',
#        'srch_children_count', 'srch_room_count', 'srch_saturday_night_bool',
#        'random_bool', 'click_bool', 'booking_bool'],
#       dtype='object')

# %% [markdown]
# # Data Analysis and Visualizations

# %%
import seaborn as sns
import pandas as pd

# Load the data into a pandas dataframe
# data = pd.read_csv("data.csv")

# Compute the correlation matrix
corr = train.corr()

# Create a heatmap of the correlation matrix
sns.heatmap(corr, cmap="coolwarm", annot=True)
# Out:
# /tmp/ipykernel_34/503634475.py:8: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = train.corr()
# <AxesSubplot: >

# %% [markdown]
# ****After Seeing the result we may see that either mistake or user is looking for Luxurious suits

# %%
train['price_usd'].describe()
# Out:
# count    4.958347e+06
# mean     2.542096e+02
# std      1.600124e+04
# min      0.000000e+00
# 25%      8.500000e+01
# 50%      1.220000e+02
# 75%      1.849600e+02
# max      1.972633e+07
# Name: price_usd, dtype: float64

# %%
train= train.loc[train['price_usd'] < 5584]

# %% [markdown]
# # Time Series Data Visualization

# %%
train.plot(x='date_time', y = 'price_usd', figsize = (20,5))
plt.xlabel('Date time')
plt.ylabel('Price in USD')
plt.title('Time Series of room price by date time of search')
# Out:
# Text(0.5, 1.0, 'Time Series of room price by date time of search')

# %% [markdown]
# # Price Analysis count of Saturday night or Non-Saturday Night

# %%
a = train.loc[train['srch_saturday_night_bool'] == 0, 'price_usd']
b = train.loc[train['srch_saturday_night_bool'] == 1, 'price_usd']
plt.figure(figsize=(20, 6))
plt.hist(a, bins = 50, alpha=0.5, label='Search Non-Sat Night')
plt.hist(b, bins = 50, alpha=0.5, label='Search Sat Night')
plt.legend(loc='upper right')
plt.xlabel('Price\n Price is more stable and lower when searching Non-Saturday night and price goes up when searching Saturday night', fontsize = 18)
plt.ylabel('Count', fontsize = 18)
plt.title("Price Comperision between Working day Night vs Saturday Night")
plt.show();

# %% [markdown]
# # Different Model Approach

# %% [markdown]
# Different Model Approach

# %%
import matplotlib.dates as md
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.covariance import EllipticEnvelope
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM
from mpl_toolkits.mplot3d import Axes3D

# %%
data = train[['price_usd', 'srch_booking_window', 'srch_saturday_night_bool']]
n_cluster = range(1, 20)
kmeans = [KMeans(n_clusters=i).fit(data) for i in n_cluster]
scores = [kmeans[i].score(data) for i in range(len(kmeans))]

fig, ax = plt.subplots(figsize=(20,6))
ax.plot(n_cluster, scores)
plt.xlabel('Number of Clusters', fontname="Times New Roman",fontweight="bold")
plt.ylabel('Score',fontname="Times New Roman",fontweight="bold")
plt.title("Elbow Curve",fontname="Times New Roman",fontweight="bold")
plt.show();
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# 1. Based on our observations, it appears that once we reach 10 clusters, the amount of variance does not significantly change.
# 2. Therefore, it is reasonable to conclude that training the model with 10 clusters would be sufficient.

# %%
data = train[['price_usd', 'srch_booking_window', 'srch_saturday_night_bool']]
X = data.values
X_std = StandardScaler().fit_transform(X)
mean_vec = np.mean(X_std, axis=0)
cov_mat = np.cov(X_std.T)
eig_vals, eig_vecs = np.linalg.eig(cov_mat)
eig_pairs = [ (np.abs(eig_vals[i]),eig_vecs[:,i]) for i in range(len(eig_vals))]
eig_pairs.sort(key = lambda x: x[0], reverse= True)
tot = sum(eig_vals)
var_exp = [(i/tot)*100 for i in sorted(eig_vals, reverse=True)] # Individual explained variance
cum_var_exp = np.cumsum(var_exp) # Cumulative explained variance

plt.figure(figsize=(20, 6))
plt.bar(range(len(var_exp)), var_exp, alpha=0.3, align='center', label='individual explained variance', color = 'g')
plt.step(range(len(cum_var_exp)), cum_var_exp, where='mid',label='cumulative explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal components')
plt.legend(loc='best')
plt.show();

# %%
# Take useful feature and standardize them
data = train[['price_usd', 'srch_booking_window', 'srch_saturday_night_bool']]
X_std = StandardScaler().fit_transform(X)
data = pd.DataFrame(X_std)
# reduce to 2 important features
pca = PCA(n_components=2)
data = pca.fit_transform(data)
# standardize these 2 new features
scaler = StandardScaler()
np_scaled = scaler.fit_transform(data)
data = pd.DataFrame(np_scaled)

# %%
kmeans = [KMeans(n_clusters=i).fit(data) for i in n_cluster]
train['cluster'] = kmeans[9].predict(data)
train.index = data.index
train['principal_feature1'] = data[0]
train['principal_feature2'] = data[1]
train['cluster'].value_counts()
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /tmp/ipykernel_34/1616152466.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['cluster'] = kmeans[9].predict(data)
# /tmp/ipykernel_34/1616152466.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['principal_feature1'] = data[0]
# /tmp/ipykernel_34/1616152466.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['principal_feature2'] = data[1]
# 4    1289079
# 0    1156419
# 8     762807
# 1     755065
# 3     394857
# 6     342275
# 9     125491
# 2     112285
# 7      15611
# 5       1726
# Name: cluster, dtype: int64

# %%
train.head()
# Out:
#    srch_id            date_time  site_id  visitor_location_country_id  \
# 0        1  2013-04-04 08:32:15       12                          187
# 1        1  2013-04-04 08:32:15       12                          187
# 2        1  2013-04-04 08:32:15       12                          187
# 3        1  2013-04-04 08:32:15       12                          187
# 4        1  2013-04-04 08:32:15       12                          187
#
#    prop_country_id  prop_id  prop_starrating  prop_brand_bool  \
# 0              219      893                3                1
# 1              219    10404                4                1
# 2              219    21315                3                1
# 3              219    27348                2                1
# 4              219    29604                4                1
#
#    prop_location_score1  prop_log_historical_price  ...  srch_adults_count  \
# 0                  2.83                       4.95  ...                  4
# 1                  2.20                       5.03  ...                  4
# 2                  2.20                       4.92  ...                  4
# 3                  2.83                       4.39  ...                  4
# 4                  2.64                       4.93  ...                  4
#
#    srch_children_count  srch_room_count  srch_saturday_night_bool  \
# 0                    0                1                         1
# 1                    0                1                         1
# 2                    0                1                         1
# 3                    0                1                         1
# 4                    0                1                         1
#
#    random_bool  click_bool  booking_bool  cluster  principal_feature1  \
# 0            1           0             0        4           -1.079238
# 1            1           0             0        4           -0.811390
# 2            1           0             0        1           -0.774605
# 3            1           0             0        9            0.942715
# 4            1           0             0        4           -0.921664
#
#    principal_feature2
# 0            0.559049
# 1            0.837383
# 2            0.875609
# 3            2.660162
# 4            0.722793
#
# [5 rows x 26 columns]

# %%
# plot the different clusters with the 2 main features apply (PCA)
fig, ax = plt.subplots(figsize=(10,6))
colors = {0:'red', 1:'blue', 2:'green', 3:'pink', 4:'black', 5:'orange', 6:'cyan', 7:'yellow', 8:'brown', 9:'purple', 10:'white', 11: 'grey'}
ax.scatter(train['principal_feature1'], train['principal_feature2'], c=train["cluster"].apply(lambda x: colors[x]))
plt.show();

# %% [markdown]
# 2 srch_children_count, price_usd', 'srch_booking_window', 'srch_saturday_night_bool'
# 3 price_usd, srch_children_count,click_bool, booking_bool
# 4.prop_starrating, prop_brand_bool,srch_booking_window,click_bool,booking_bool
# 5.srch_length_of_stay, srch_destination_id, click_bool, booking_bool
#
# Index(['srch_id', 'date_time', 'site_id', 'visitor_location_country_id',
#        'prop_country_id', 'prop_id', 'prop_starrating', 'prop_brand_bool',
#        'prop_location_score1', 'prop_log_historical_price', 'position',
#        'price_usd', 'promotion_flag', 'srch_destination_id',
#        'srch_length_of_stay', 'srch_booking_window', 'srch_adults_count',
#        'srch_children_count', 'srch_room_count', 'srch_saturday_night_bool',
#        'random_bool', 'click_bool', 'booking_bool'],
#       dtype='object')

# %%
data = train[['srch_children_count','price_usd', 'srch_booking_window', 'srch_saturday_night_bool']]
n_cluster = range(1, 20)
kmeans = [KMeans(n_clusters=i).fit(data) for i in n_cluster]
scores = [kmeans[i].score(data) for i in range(len(kmeans))]

fig, ax = plt.subplots(figsize=(20,6))
ax.plot(n_cluster, scores)
plt.xlabel('Number of Clusters', fontname="Times New Roman",fontweight="bold")
plt.ylabel('Score',fontname="Times New Roman",fontweight="bold")
plt.title("Elbow Curve",fontname="Times New Roman",fontweight="bold")
plt.show();
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
data = train[['price_usd', 'srch_children_count','click_bool', 'booking_bool']]
n_cluster = range(1, 20)
kmeans = [KMeans(n_clusters=i).fit(data) for i in n_cluster]
scores = [kmeans[i].score(data) for i in range(len(kmeans))]

fig, ax = plt.subplots(figsize=(20,6))
ax.plot(n_cluster, scores)
plt.xlabel('Number of Clusters', fontname="Times New Roman",fontweight="bold")
plt.ylabel('Score',fontname="Times New Roman",fontweight="bold")
plt.title("Elbow Curve",fontname="Times New Roman",fontweight="bold")
plt.show();
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
data = train[['prop_starrating', 'prop_brand_bool','srch_booking_window','click_bool', 'booking_bool']]
n_cluster = range(1, 30)
kmeans = [KMeans(n_clusters=i).fit(data) for i in n_cluster]
scores = [kmeans[i].score(data) for i in range(len(kmeans))]

fig, ax = plt.subplots(figsize=(20,6))
ax.plot(n_cluster, scores)
plt.xlabel('Number of Clusters', fontname="Times New Roman",fontweight="bold")
plt.ylabel('Score',fontname="Times New Roman",fontweight="bold")
plt.title("Elbow Curve",fontname="Times New Roman",fontweight="bold")
plt.show();
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
data = train[['srch_length_of_stay', 'srch_destination_id','click_bool', 'booking_bool']]
n_cluster = range(1, 30)
kmeans = [KMeans(n_clusters=i).fit(data) for i in n_cluster]
scores = [kmeans[i].score(data) for i in range(len(kmeans))]

fig, ax = plt.subplots(figsize=(20,6))
ax.plot(n_cluster, scores)
plt.xlabel('Number of Clusters', fontname="Times New Roman",fontweight="bold")
plt.ylabel('Score',fontname="Times New Roman",fontweight="bold")
plt.title("Elbow Curve",fontname="Times New Roman",fontweight="bold")
plt.show();
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
